# %% [markdown]
# # Pre-processing

# %% [markdown]
# 1. take out pre-trial signals from all C channels and cut it into N segmentations with length L --> N (C*L matrixes)
# 2. element-wise addition (matrixes) & mean value --> BaseMean (C*L matrixes) --> basic emotion state
# 3. RawEEG: segment raw EEG into M (C*L matrixes)
# 4. BaseRemoved = RawEEG - BaseMean
# 5. concatenate all BaseRermoved matrixes into a big matrix (size the same with raw EEG)

# %%
import scipy.io as sio
import argparse
import os
import sys
import numpy as np
import pandas as pd
import time
import pickle

# %%
np.random.seed(0) # the same pool to choose random

# %%
def data_1Dto2D(data, Y=9, X=9): # input: data
    # create the 2D matrix
    data_2D = np.zeros([Y, X])
    data_2D[0] = (0, 0, 0, data[0], 0, data[16], 0, 0, 0)
    data_2D[1] = (0, 0, 0, data[1], 0, data[17], 0, 0, 0)
    data_2D[2] = (data[3], 0, data[2], 0, data[18], 0, data[19], 0, data[20])
    data_2D[3] = (0, data[4], 0, data[5], 0, data[22], 0, data[21], 0)
    data_2D[4] = (data[7], 0, data[6], 0, data[23], 0, data[24], 0, data[25])
    data_2D[5] = (0, data[8], 0, data[9], 0, data[27], 0, data[26], 0)
    data_2D[6] = (data[11], 0, data[10], 0, data[15], 0, data[28], 0, data[29])
    data_2D[7] = (0, 0, 0, data[12], 0, data[30], 0, 0, 0)
    data_2D[8] = (0, 0, 0, data[13], data[14], data[31], 0, 0, 0)
    return data_2D

# %%
def feature_normalize(data):
    mean = data[data.nonzero()].mean() # exclude zero elements
    sigma = data[data.nonzero()].std()
    data_normalized = data
    data_normalized[data_normalized.nonzero()] = (data_normalized[data_normalized.nonzero()] - mean)/sigma
    return data_normalized

# %%
def norm_dataset(dataset_1D):
    norm_dataset_1D = np.zeros([dataset_1D.shape[0], 32])
    for i in range(dataset_1D.shape[0]):
        norm_dataset_1D[i] = feature_normalize(dataset_1D[i])
    return norm_dataset_1D

# %%
def dataset_1Dto2D(dataset_1D):
    dataset_2D = np.zeros([dataset_1D.shape[0], 9, 9])
    for i in range(dataset_1D.shape[0]):
        dataset_2D[i] = data_1Dto2D(dataset_1D[i])
    return dataset_2D

# %%
def norm_dataset_1Dto2D(dataset_1D):
    norm_dataset_2D = np.zeros([dataset_1D.shape[0], 9, 9])
    for i in range(dataset_1D.shape[0]):
        norm_dataset_2D[i] = feature_normalize(data_1Dto2D(dataset_1D[i]))
    return norm_dataset_2D

# %%
def windows(data, size):
    start = 0
    while((start + size) < data.shape[0]):
        yield int(start), int(start + size)
        start += size

# %%
def segment_signal_without_transition(data, label, label_index, window_size):
    for(start, end) in windows(data, window_size):
        if((len(data[start:end]) == window_size)):
            if(start == 0):
                segments = data[start:end]
                segments = np.vstack([segments, data[start:end]])
                
                labels = np.array(label[label_index])
                labels = np.append(labels, np.array(label[label_index]))
            else:
                segments = segments = np.vstack([segments, data[start:end]])
                labels = np.append(labels, np.array(label[label_index]))
    return segments, labels

# %%
def apply_mixup(dataset_file, window_size, label, yes_or_no):
    print("Processing", dataset_file, "...........")
    data_file_in = sio.loadmat(dataset_file)
    data_in = data_file_in["data"].transpose(0, 2, 1)
    # 0 valence, 1 arousal, 2 dominace, 3 liking
    if label == "valence":
        label = 0
    elif label == "arousal":
        label = 1
    label_in = data_file_in["labels"][:, label]>5
    label_inter = np.empty([0])
    data_inter_cnn = np.empty([0, window_size, 9, 9])
    data_inter_rnn = np.empty([0, window_size, 32])
    trials = data_in.shape[0]
    
    # Data pre-processing
    for trial in range(0, trials):
        if yes_or_no == "yes":
            base_signal = (data_in[trial, 0:128, 0:32] + data_in[trial, 128:256, 0:32] + data_in[trial, 256:384, 0:32])/3
        else:
            base_signal = 0
        data = data_in[trial, 384:8064, 0:32]
        # Compute the deviation between baseline signals and experimental signals
        for i in range(0, 60):
            data[i*128:(i+1)*128,0:32] = data[i*128:(i+1)*128,0:32] - base_signal
        label_index = trial
        # Read the data and label
        data = norm_dataset(data)
        data, label = segment_signal_without_transition(data, label_in, label_index, window_size)
        # CNN data process
        data_cnn = dataset_1Dto2D(data)
        data_cnn = data_cnn.reshape(int(data_cnn.shape[0]/window_size), window_size, 9, 9)
        # RNN data process
        data_rnn = data.reshape(int(data.shape[0]/window_size), window_size, 32)
        # Append new data and label
        data_inter_cnn = np.vstack([data_inter_cnn, data_cnn])
        data_inter_rnn = np.vstack([data_inter_rnn, data_rnn])
        label_inter = np.append(label_inter, label)
        
#     print("total cnn size: ", data_inter_cnn.shape)
#     print("total rnn size: ", data_inter_rnn.shape)
#     print("total label size: ", label_inter.shape)
    
    #shuffle data
    index = np.array(range(0, len(label_inter)))
    np.random.shuffle(index)
    shuffled_data_cnn = data_inter_cnn[index]
    shuffled_data_rnn = data_inter_rnn[index]
    shuffled_label = label_inter[index]
    return shuffled_data_cnn, shuffled_data_rnn, shuffled_label, record

# %%
begin = time.time()
print("time begin: ", time.localtime())
dataset_dir = "/Users/zouhao/Desktop/EEGResearch/Dataset/"
window_size = 128
output_dir = "/Users/zouhao/Desktop/EEGResearch/deap_shuffled_data/"
print("Input arousal/valence yes/no: ")
label_class, suffix = input().split()
# Get directory name for one subject
record_list = [task for task in os.listdir(dataset_dir) if os.path.isfile(os.path.join(dataset_dir, task))]
output_dir = output_dir+suffix+"_"+label_class+"/"
if os.path.isdir(output_dir) == False:
    os.makedirs(output_dir)
print(record_list)

for record in record_list:
    file = os.path.join(dataset_dir, record)
    shuffled_cnn_data,shuffled_rnn_data,shuffled_label,record = apply_mixup(file,window_size,label_class,suffix)
    output_data_cnn = output_dir+record+"_win_"+str(window_size)+"_cnn_dataset.pkl"
    output_data_rnn = output_dir+record+"_win_"+str(window_size)+"_rnn_dataset.pkl"
    output_label = output_dir+record+"_win_"+str(window_size)+"_labels.pkl"
    
    with open(output_data_cnn, "wb") as fp:
        pickle.dump(shuffled_cnn_data, fp, protocol=4)
    with open(output_data_rnn, "wb") as fp:
        pickle.dump(shuffled_rnn_data, fp, protocol=4)
    with open(output_label, "wb") as fp:
        pickle.dump(shuffled_label, fp)
    end = time.time()
    print("end time: ", time.localtime())
    print("time consuming: ", (end-begin))
# Out:
# time begin:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=13, tm_sec=25, tm_wday=1, tm_yday=210, tm_isdst=1)
# Input arousal/valence yes/no:
# arousal yes
# ['s01.mat', 's15.mat', 's29.mat', 's28.mat', 's14.mat', 's16.mat', 's02.mat', 's03.mat', 's17.mat', 's13.mat', 's07.mat', 's06.mat', 's12.mat', 's04.mat', 's10.mat', 's11.mat', 's05.mat', 's20.mat', 's08.mat', 's09.mat', 's21.mat', 's23.mat', 's22.mat', 's32.mat', 's26.mat', 's27.mat', 's19.mat', 's25.mat', 's31.mat', 's30.mat', 's24.mat', 's18.mat']
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s01.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=14, tm_sec=11, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  45.92270803451538
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s15.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=14, tm_sec=43, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  78.14303803443909
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s29.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=15, tm_sec=19, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  114.15478301048279
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s28.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=15, tm_sec=54, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  149.11923217773438
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s14.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=16, tm_sec=27, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  182.34007573127747
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s16.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=17, tm_sec=0, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  215.23651099205017
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s02.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=17, tm_sec=33, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  247.7137589454651
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s03.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=18, tm_sec=5, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  280.25340390205383
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s17.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=18, tm_sec=38, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  313.27010011672974
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s13.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=19, tm_sec=11, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  346.66902899742126
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s07.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=19, tm_sec=47, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  382.5254080295563
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s06.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=20, tm_sec=31, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  425.99857997894287
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s12.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=21, tm_sec=14, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  469.1152799129486
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s04.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=21, tm_sec=55, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  509.7495539188385
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s10.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=22, tm_sec=34, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  549.0464930534363
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s11.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=23, tm_sec=12, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  587.2412807941437
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s05.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=23, tm_sec=52, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  627.2774560451508
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s20.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=24, tm_sec=31, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  665.991662979126
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s08.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=25, tm_sec=9, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  704.2108707427979
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s09.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=25, tm_sec=49, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  743.7014138698578
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s21.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=26, tm_sec=29, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  784.5090630054474
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s23.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=27, tm_sec=8, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  822.9135520458221
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s22.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=27, tm_sec=46, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  861.4545118808746
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s32.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=28, tm_sec=29, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  903.8067200183868
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s26.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=29, tm_sec=6, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  941.251494884491
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s27.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=29, tm_sec=43, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  978.5897059440613
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s19.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=30, tm_sec=22, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  1017.1161890029907
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s25.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=31, tm_sec=0, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  1054.7551651000977
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s31.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=31, tm_sec=37, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  1092.3966920375824
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s30.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=32, tm_sec=15, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  1130.127456188202
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s24.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=32, tm_sec=52, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  1167.3899319171906
# Processing /Users/zouhao/Desktop/EEGResearch/Dataset/s18.mat ...........
# total cnn size:  (2400, 128, 9, 9)
# total rnn size:  (2400, 128, 32)
# total label size:  (2400,)
# end time:  time.struct_time(tm_year=2020, tm_mon=7, tm_mday=28, tm_hour=2, tm_min=33, tm_sec=36, tm_wday=1, tm_yday=210, tm_isdst=1)
# time consuming:  1211.4372389316559
